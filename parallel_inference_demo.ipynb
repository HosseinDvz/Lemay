# %% [markdown]
# # Parallel Classification via FastAPI
# ### This notebook reads a CSV file containing website content, sends parallel POST requests to a running FastAPI inference container, and appends the predicted labels to the original data. To validate the performance of the parallelized setup, both parallel and sequential inference times are measured and compared.

# %% [markdown]
# ## Data Preparation
# ### This section prepares input data for inference by loading and concatenating multiple CSV files.
# ### Each CSV is expected to contain scraped website data, including the site name and its corresponding content.

# %%
import glob
import pandas as pd

# Load and concatenate all matching chunk files
all_files = sorted(glob.glob("scrapingResults/chunk_*_results.csv"))
df_list = [pd.read_csv(f).dropna(subset=["website", "content"]) for f in all_files]
df = pd.concat(df_list, ignore_index=True)

# Add dummy row at index 0 because of not getting the right label at index 0 -TEST falied - something is wrong with the first row
# dummy_row = pd.DataFrame([{"website": "example.com", "content": "placeholder content"}])  # or content=None
# df = pd.concat([dummy_row, df], ignore_index=True)

print(f"Total records loaded: {len(df)}")
df.head()
# Out:
# Total records loaded: 57
#                       website  \
# 0   https://www.wikipedia.org
# 1         https://www.bbc.com
# 2         https://www.cnn.com
# 3     https://www.nytimes.com
# 4  https://www.britannica.com
#
#                                              content
# 0  Wikipedia The Free Encyclopedia English 6,974,...
# 1  Skip to content Watch Live Home News Sport Bus...
# 2  CNN values your feedback 1. How relevant is th...
# 3  Skip to content Skip to site index SKIP ADVERT...
# 4  Explore Search Britannica Click here to search...

# %% [markdown]
# ### 🚀 Parallel Inference with `asyncio` and `httpx`
#
# To improve classification speed, we leverage Python's `asyncio` and `httpx.AsyncClient` to send multiple inference requests concurrently to the FastAPI server.
#
# Key components:
# - `asyncio.Semaphore(9)`: Limits the number of concurrent requests to avoid overwhelming the server. It's recommended to set this to one or two (based on how to run the app, by image or without image locally) less than the number of Gunicorn due to a special case in the dataset.
# - `fetch_parallel(...)`: Asynchronously sends one POST request for classification.
# - `classify_parallel(df)`: Iterates over all rows in the input DataFrame and schedules async tasks for classification.

# %%
import httpx
import asyncio
import nest_asyncio
import time

nest_asyncio.apply()
API_URL = "http://localhost:8000/classify"
semaphore = asyncio.Semaphore(3)

async def fetch_parallel(session, website, content):
    async with semaphore:
        try:
            response = await session.post(API_URL, json={"website": website, "content": content}, timeout=15.0)
            return response.json().get("label", "error")
        except Exception:
            return "error"

async def classify_parallel(df):
    async with httpx.AsyncClient() as session:
        tasks = [fetch_parallel(session, row["website"], row["content"]) for _, row in df.iterrows()]
        return await asyncio.gather(*tasks)

# ⏱️ Time parallel run
start = time.time()
df["predicted_label_parallel"] = asyncio.run(classify_parallel(df))
end = time.time()
print(f"✅ Parallel inference time: {end - start:.2f} sec")
df
# Out:
# ✅ Parallel inference time: 120.25 sec
#                                website  \
# 0            https://www.wikipedia.org
# 1                  https://www.bbc.com
# 2                  https://www.cnn.com
# 3              https://www.nytimes.com
# 4           https://www.britannica.com
# 5   https://www.nationalgeographic.com
# 6              https://www.reuters.com
# 7                  https://www.npr.org
# 8            https://www.bloomberg.com
# 9            https://www.bloomberg.com
# 10           https://www.aljazeera.com
# 11             https://www.history.com
# 12                https://www.imdb.com
# 13       https://www.stackoverflow.com
# 14              https://www.medium.com
# 15            https://www.engadget.com
# 16         https://www.producthunt.com
# 17               https://www.wired.com
# 18         https://www.livescience.com
# 19          https://www.healthline.com
# 20          https://www.mayoclinic.org
# 21                 https://www.cdc.gov
# 22                 https://www.nih.gov
# 23                  https://www.un.org
# 24          https://www.whitehouse.gov
# 25                  https://www.gov.uk
# 26               https://www.canada.ca
# 27                 https://www.ted.com
# 28            https://www.coursera.org
# 29                 https://www.edx.org
# 30               https://www.udemy.com
# 31            https://www.academia.edu
# 32        https://www.researchgate.net
# 33             https://www.archive.org
# 34               https://www.jstor.org
# 35            https://www.bankrate.com
# 36          https://www.nerdwallet.com
# 37                https://www.fool.com
# 38         https://www.ycombinator.com
# 39          https://www.crunchbase.com
# 40           https://www.glassdoor.com
# 41            https://www.linkedin.com
# 42              https://www.indeed.com
# 43             https://www.monster.com
# 44         https://www.simplyhired.com
# 45              https://www.docker.com
# 46           https://www.kubernetes.io
# 47              https://www.jenkins.io
# 48             https://www.netlify.com
# 49              https://www.vercel.com
# 50          https://www.cloudflare.com
# 51              https://www.heroku.com
# 52              https://aws.amazon.com
# 53            https://cloud.google.com
# 54        https://www.digitalocean.com
# 55              https://www.linode.com
# 56           https://www.ibm.com/cloud
#
#                                               content  \
# 0   Wikipedia The Free Encyclopedia English 6,974,...
# 1   Skip to content Watch Live Home News Sport Bus...
# 2   CNN values your feedback 1. How relevant is th...
# 3   Skip to content Skip to site index SKIP ADVERT...
# 4   Explore Search Britannica Click here to search...
# 5   Latest Stories Subscribe for full access to re...
# 6         Please enable JS and disable any ad blocker
# 7   Accessibility links Skip to main content Keybo...
# 8   Bloomberg Need help? Contact us We've detected...
# 9   Bloomberg Need help? Contact us We've detected...
# 10  Skip links Skip to Featured Content Skip to Co...
# 11  Open navigation Close navigation Home Shows Th...
# 12                                      403 Forbidden
# 13                               302 Found cloudflare
# 14                   301 Moved Permanently cloudflare
# 15  Sign in Advertisement Advertisement Advertisem...
# 16          Enable JavaScript and cookies to continue
# 17  Skip to main content Open Navigation Menu WIRE...
# 18  Skip to main content Open menu Close menu Live...
# 19  Health Conditions Health Conditions All Breast...
# 20  Skip to content Care at Mayo Clinic Patient-Ce...
# 21  Skip to site content Skip to search An officia...
# 22  Skip to main content U.S. Department of Health...
# 23  403 ERROR The request could not be satisfied. ...
# 24  Menu President Donald J. Trump The White House...
# 25  Cookies on GOV.UK We use some essential cookie...
# 26  Canada.ca / Gouvernement du Canada Government ...
# 27  Ideas change everything WATCH TED Talks Browse...
# 28  For Individuals For Businesses For Universitie...
# 29  Learn Search Most popular programs CS50's Intr...
# 30                                          Forbidden
# 31  Skip to main content Academia.edu no longer su...
# 32  Access denied You do not have access to www.re...
# 33                             302 Found nginx/1.24.0
# 34  Explore the world’s knowledge, cultures, and i...
# 35  Skip to Main Content Banking All Banking Check...
# 36  Credit cards Credit cards Explore more credit ...
# 37  ▲ S&P 500 + ---% | ▲ Stock Advisor + ---% Join...
# 38  About What Happens at YC? Apply YC Interview G...
# 39  New Resources Advanced Search Start Free Trial...
# 40  Help Us Protect Glassdoor Please help us prote...
# 41  Skip to main content Agree & Join LinkedIn By ...
# 42  Find jobs Company reviews Find salaries Sign i...
# 43  Skip to content Hire candidates with flexible ...
# 44  Please enable cookies. Sorry, you have been bl...
# 45  Docs Get Support Contact Sales Products Produc...
# 46              Redirecting to https://kubernetes.io/
# 47  Jenkins Build great things at any scale The le...
# 48  Deploy from Windsurf to the web in just one cl...
# 49                                     Redirecting...
# 50  Support Languages English English (United King...
# 51  Search overlay panel for performing site-wide ...
# 52  Skip to main content Click here to return to A...
# 53  Get $300 in free credits and free usage of 20+...
# 54  Blog Docs Get Support Contact Sales DigitalOce...
# 55  Close X Skip to main content Search Docs Blog ...
# 56  IBM Cloud: AI-ready, secure, and hybrid by des...
#
#    predicted_label_parallel predicted_label_sync
# 0                    health               health
# 1                      news                 news
# 2                      news                 news
# 3                      news                 news
# 4               educational          educational
# 5                      news                 news
# 6                    health               health
# 7                      news                 news
# 8                      news                 news
# 9                      news                 news
# 10                     news                 news
# 11              educational          educational
# 12                  unknown              unknown
# 13                  unknown              unknown
# 14             social media         social media
# 15                     news                 news
# 16                     news                 news
# 17                     news                 news
# 18                     news                 news
# 19                   health               health
# 20              educational          educational
# 21                   health               health
# 22                   health               health
# 23                  unknown              unknown
# 24                     news                 news
# 25              educational          educational
# 26             social media         social media
# 27              educational          educational
# 28              educational          educational
# 29                  finance              finance
# 30              educational          educational
# 31              educational          educational
# 32                     news                 news
# 33                  unknown              unknown
# 34              educational          educational
# 35              educational          educational
# 36              educational          educational
# 37                  finance              finance
# 38              educational          educational
# 39                     news                 news
# 40                     news                 news
# 41              educational          educational
# 42                     news                 news
# 43              educational          educational
# 44                     news                 news
# 45              educational          educational
# 46             social media         social media
# 47                     news                 news
# 48                     news                 news
# 49             social media         social media
# 50              educational          educational
# 51                     news                 news
# 52                   health               health
# 53                     news                 news
# 54                     news                 news
# 55              educational          educational
# 56                     news                 news

# %% [markdown]
# ### 🐢 Sequential Inference with `httpx.post`
#
# To verify the effectiveness of parallel inference, this section measures the time taken to classify website content sequentially, one-by-one,
# using synchronous HTTP requests with the `httpx` library.

# %%
def classify_sync(df):
    labels = []
    for _, row in df.iterrows():
        try:
            response = httpx.post(API_URL, json={"website": row["website"], "content": row["content"]}, timeout=15.0)
            labels.append(response.json().get("label", "error"))
        except Exception:
            labels.append("error")
    return labels

start = time.time()
df["predicted_label_sync"] = classify_sync(df)
end = time.time()
print(f"🐢 Sequential inference time: {end - start:.2f} sec")
df
# Out:
# 🐢 Sequential inference time: 137.98 sec
#                                website  \
# 0            https://www.wikipedia.org
# 1                  https://www.bbc.com
# 2                  https://www.cnn.com
# 3              https://www.nytimes.com
# 4           https://www.britannica.com
# 5   https://www.nationalgeographic.com
# 6              https://www.reuters.com
# 7                  https://www.npr.org
# 8            https://www.bloomberg.com
# 9            https://www.bloomberg.com
# 10           https://www.aljazeera.com
# 11             https://www.history.com
# 12                https://www.imdb.com
# 13       https://www.stackoverflow.com
# 14              https://www.medium.com
# 15            https://www.engadget.com
# 16         https://www.producthunt.com
# 17               https://www.wired.com
# 18         https://www.livescience.com
# 19          https://www.healthline.com
# 20          https://www.mayoclinic.org
# 21                 https://www.cdc.gov
# 22                 https://www.nih.gov
# 23                  https://www.un.org
# 24          https://www.whitehouse.gov
# 25                  https://www.gov.uk
# 26               https://www.canada.ca
# 27                 https://www.ted.com
# 28            https://www.coursera.org
# 29                 https://www.edx.org
# 30               https://www.udemy.com
# 31            https://www.academia.edu
# 32        https://www.researchgate.net
# 33             https://www.archive.org
# 34               https://www.jstor.org
# 35            https://www.bankrate.com
# 36          https://www.nerdwallet.com
# 37                https://www.fool.com
# 38         https://www.ycombinator.com
# 39          https://www.crunchbase.com
# 40           https://www.glassdoor.com
# 41            https://www.linkedin.com
# 42              https://www.indeed.com
# 43             https://www.monster.com
# 44         https://www.simplyhired.com
# 45              https://www.docker.com
# 46           https://www.kubernetes.io
# 47              https://www.jenkins.io
# 48             https://www.netlify.com
# 49              https://www.vercel.com
# 50          https://www.cloudflare.com
# 51              https://www.heroku.com
# 52              https://aws.amazon.com
# 53            https://cloud.google.com
# 54        https://www.digitalocean.com
# 55              https://www.linode.com
# 56           https://www.ibm.com/cloud
#
#                                               content  \
# 0   Wikipedia The Free Encyclopedia English 6,974,...
# 1   Skip to content Watch Live Home News Sport Bus...
# 2   CNN values your feedback 1. How relevant is th...
# 3   Skip to content Skip to site index SKIP ADVERT...
# 4   Explore Search Britannica Click here to search...
# 5   Latest Stories Subscribe for full access to re...
# 6         Please enable JS and disable any ad blocker
# 7   Accessibility links Skip to main content Keybo...
# 8   Bloomberg Need help? Contact us We've detected...
# 9   Bloomberg Need help? Contact us We've detected...
# 10  Skip links Skip to Featured Content Skip to Co...
# 11  Open navigation Close navigation Home Shows Th...
# 12                                      403 Forbidden
# 13                               302 Found cloudflare
# 14                   301 Moved Permanently cloudflare
# 15  Sign in Advertisement Advertisement Advertisem...
# 16          Enable JavaScript and cookies to continue
# 17  Skip to main content Open Navigation Menu WIRE...
# 18  Skip to main content Open menu Close menu Live...
# 19  Health Conditions Health Conditions All Breast...
# 20  Skip to content Care at Mayo Clinic Patient-Ce...
# 21  Skip to site content Skip to search An officia...
# 22  Skip to main content U.S. Department of Health...
# 23  403 ERROR The request could not be satisfied. ...
# 24  Menu President Donald J. Trump The White House...
# 25  Cookies on GOV.UK We use some essential cookie...
# 26  Canada.ca / Gouvernement du Canada Government ...
# 27  Ideas change everything WATCH TED Talks Browse...
# 28  For Individuals For Businesses For Universitie...
# 29  Learn Search Most popular programs CS50's Intr...
# 30                                          Forbidden
# 31  Skip to main content Academia.edu no longer su...
# 32  Access denied You do not have access to www.re...
# 33                             302 Found nginx/1.24.0
# 34  Explore the world’s knowledge, cultures, and i...
# 35  Skip to Main Content Banking All Banking Check...
# 36  Credit cards Credit cards Explore more credit ...
# 37  ▲ S&P 500 + ---% | ▲ Stock Advisor + ---% Join...
# 38  About What Happens at YC? Apply YC Interview G...
# 39  New Resources Advanced Search Start Free Trial...
# 40  Help Us Protect Glassdoor Please help us prote...
# 41  Skip to main content Agree & Join LinkedIn By ...
# 42  Find jobs Company reviews Find salaries Sign i...
# 43  Skip to content Hire candidates with flexible ...
# 44  Please enable cookies. Sorry, you have been bl...
# 45  Docs Get Support Contact Sales Products Produc...
# 46              Redirecting to https://kubernetes.io/
# 47  Jenkins Build great things at any scale The le...
# 48  Deploy from Windsurf to the web in just one cl...
# 49                                     Redirecting...
# 50  Support Languages English English (United King...
# 51  Search overlay panel for performing site-wide ...
# 52  Skip to main content Click here to return to A...
# 53  Get $300 in free credits and free usage of 20+...
# 54  Blog Docs Get Support Contact Sales DigitalOce...
# 55  Close X Skip to main content Search Docs Blog ...
# 56  IBM Cloud: AI-ready, secure, and hybrid by des...
#
#    predicted_label_parallel predicted_label_sync
# 0                    health               health
# 1                      news                 news
# 2                      news                 news
# 3                      news                 news
# 4               educational          educational
# 5                      news                 news
# 6                    health               health
# 7                      news                 news
# 8                      news                 news
# 9                      news                 news
# 10                     news                 news
# 11              educational          educational
# 12                  unknown              unknown
# 13                  unknown              unknown
# 14             social media         social media
# 15                     news                 news
# 16                     news                 news
# 17                     news                 news
# 18                     news                 news
# 19                   health               health
# 20              educational          educational
# 21                   health               health
# 22                   health               health
# 23                  unknown              unknown
# 24                     news                 news
# 25              educational          educational
# 26             social media         social media
# 27              educational          educational
# 28              educational          educational
# 29                  finance              finance
# 30              educational          educational
# 31              educational          educational
# 32                     news                 news
# 33                  unknown              unknown
# 34              educational          educational
# 35              educational          educational
# 36              educational          educational
# 37                  finance              finance
# 38              educational          educational
# 39                     news                 news
# 40                     news                 news
# 41              educational          educational
# 42                     news                 news
# 43              educational          educational
# 44                     news                 news
# 45              educational          educational
# 46             social media         social media
# 47                     news                 news
# 48                     news                 news
# 49             social media         social media
# 50              educational          educational
# 51                     news                 news
# 52                   health               health
# 53                     news                 news
# 54                     news                 news
# 55              educational          educational
# 56                     news                 news

# %% [markdown]
# ### As demonstrated, parallel inference provided a slight performance improvement. However, when running the application inside a Docker container, we cannot fully leverage the benefits of parallelism due to resource constraints—some CPU resources are reserved for container overhead. For optimal performance, the application can be run directly on my machine with more gunicorn workers and concurrent connections, which I will showcase during the demo.
